# %% [markdown]
# # Data Exploration and Analysis
# The following notebook will take a look at the data sets that will be used in the recommendation engine and prep the data for use in the engine itself.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read in Data

# %%
animes_df = pd.read_csv('data/animes.csv')
users_df = pd.read_csv('data/profiles.csv')
reviews_df = pd.read_csv('data/reviews.csv')

print("Animes DF: {}\nUsers DF: {}\nReviews DF: {}".format(animes_df.shape, users_df.shape, reviews_df.shape))
# Out:
# Animes DF: (19311, 12)
# Users DF: (81727, 5)
# Reviews DF: (192112, 7)

# %% [markdown]
# ### Animes DataFrame

# %%
animes_df.head(5)
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
animes_df.genre.isnull().sum()
# Out:
# 0

# %%
genres = []
for genre_set in animes_df.genre:
    values = genre_set.strip("[]").split(",")
    values = [w.strip()[1:-1] for w in values]
    genres.extend(values)

genres = set(genres)
print("The number of genres is {}.".format(len(genres)))
print(genres)
# Out:
# The number of genres is 44.
# {'', 'Yuri', 'Slice of Life', 'Police', 'Fantasy', 'Cars', 'Vampire', 'Romance', 'Thriller', 'Mecha', 'Parody', 'Horror', 'Military', 'Sci-Fi', 'Samurai', 'Shounen', 'Shounen Ai', 'Space', 'Martial Arts', 'Dementia', 'Historical', 'Mystery', 'Kids', 'Hentai', 'Drama', 'Comedy', 'Adventure', 'Shoujo', 'School', 'Demons', 'Supernatural', 'Game', 'Super Power', 'Shoujo Ai', 'Magic', 'Ecchi', 'Action', 'Josei', 'Harem', 'Music', 'Yaoi', 'Sports', 'Seinen', 'Psychological'}

# %% [markdown]
# Notice the first element is empty. This happend when calling set(genres). We can quickly delete that.

# %%
genres = list(genres)
genres.pop(0)
print("The number of genres is {}.".format(len(genres)))
print(genres)
# Out:
# The number of genres is 43.
# ['Yuri', 'Slice of Life', 'Police', 'Fantasy', 'Cars', 'Vampire', 'Romance', 'Thriller', 'Mecha', 'Parody', 'Horror', 'Military', 'Sci-Fi', 'Samurai', 'Shounen', 'Shounen Ai', 'Space', 'Martial Arts', 'Dementia', 'Historical', 'Mystery', 'Kids', 'Hentai', 'Drama', 'Comedy', 'Adventure', 'Shoujo', 'School', 'Demons', 'Supernatural', 'Game', 'Super Power', 'Shoujo Ai', 'Magic', 'Ecchi', 'Action', 'Josei', 'Harem', 'Music', 'Yaoi', 'Sports', 'Seinen', 'Psychological']

# %%
animes_df.genre[0].find("Sports")
# Out:
# 12

# %%
def split_genres(movie):
    try:
        if movie.find(genre) > -1:
            return 1
        else:
            return 0
    except AttributeError:
        return 0

for genre in genres:
    animes_df[genre] = animes_df['genre'].apply(split_genres)

# %%
animes_df.iloc[59]
# Out:
# uid                                                            269
# title                                                       Bleach
# synopsis         Ichigo Kurosaki is an ordinary high schooler—u...
# genre            ['Action', 'Adventure', 'Comedy', 'Super Power...
# aired                                  Oct 5, 2004 to Mar 27, 2012
# episodes                                                     366.0
# members                                                    1002578
# popularity                                                      25
# ranked                                                       757.0
# score                                                         7.87
# img_url          https://cdn.myanimelist.net/images/anime/3/404...
# link                      https://myanimelist.net/anime/269/Bleach
# Yuri                                                             0
# Slice of Life                                                    0
# Police                                                           0
# Fantasy                                                          0
# Cars                                                             0
# Vampire                                                          0
# Romance                                                          0
# Thriller                                                         0
# Mecha                                                            0
# Parody                                                           0
# Horror                                                           0
# Military                                                         0
# Sci-Fi                                                           0
# Samurai                                                          0
# Shounen                                                          1
# Shounen Ai                                                       0
# Space                                                            0
# Martial Arts                                                     0
# Dementia                                                         0
# Historical                                                       0
# Mystery                                                          0
# Kids                                                             0
# Hentai                                                           0
# Drama                                                            0
# Comedy                                                           1
# Adventure                                                        1
# Shoujo                                                           0
# School                                                           0
# Demons                                                           0
# Supernatural                                                     1
# Game                                                             0
# Super Power                                                      1
# Shoujo Ai                                                        0
# Magic                                                            0
# Ecchi                                                            0
# Action                                                           1
# Josei                                                            0
# Harem                                                            0
# Music                                                            0
# Yaoi                                                             0
# Sports                                                           0
# Seinen                                                           0
# Psychological                                                    0
# Name: 59, dtype: object

# %%
top_ranked = animes_df.sort_values(by='ranked', ascending=True).drop_duplicates()
top_ranked.head(20)
# Out:
#          uid                                              title  \
# 3080    5114                   Fullmetal Alchemist: Brotherhood
# 773     9253                                        Steins;Gate
# 772    11061                             Hunter x Hunter (2011)
# 18278  32281                                     Kimi no Na wa.
# 18276  38524                 Shingeki no Kyojin Season 3 Part 2
# 18067  28977                                           Gintama°
# 18066   9969                                           Gintama'
# 18065    820                               Ginga Eiyuu Densetsu
# 18064  35180                         3-gatsu no Lion 2nd Season
# 18063  28851                                     Koe no Katachi
# 3092   15417                                Gintama': Enchousen
# 14      4181                               Clannad: After Story
# 13       918                                            Gintama
# 12     15335  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 11     34096                                           Gintama.
# 3087   32935  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...
# 3086    2904                 Code Geass: Hangyaku no Lelouch R2
# 3085   35247                         Owarimonogatari 2nd Season
# 3084   38000                                   Kimetsu no Yaiba
# 6        199                      Sen to Chihiro no Kamikakushi
#
#                                                 synopsis  \
# 3080   "In order for something to be obtained, someth...
# 773    The self-proclaimed mad scientist Rintarou Oka...
# 772    Hunter x Hunter  is set in a world where Hunte...
# 18278  Mitsuha Miyamizu, a high school girl, yearns t...
# 18276  Seeking to restore humanity’s diminishing hope...
# 18067  Gintoki, Shinpachi, and Kagura return as the f...
# 18066  After a one-year hiatus, Shinpachi Shimura ret...
# 18065  The 150-year-long stalemate between the two in...
# 18064  Now in his second year of high school, Rei Kir...
# 18063  As a wild youth, elementary school student Sho...
# 3092   While Gintoki Sakata was away, the Yorozuya fo...
# 14     Clannad: After Story , the sequel to the criti...
# 13     The Amanto, aliens from outer space, have inva...
# 12     When Gintoki apprehends a movie pirate at a pr...
# 11     After joining the resistance against the bakuf...
# 3087   After the victory against Aoba Jousai High, Ka...
# 3086   One year has passed since the Black Rebellion,...
# 3085   Following an encounter with oddity specialist ...
# 3084   Ever since the death of his father, the burden...
# 6      Stubborn, spoiled, and naïve, 10-year-old Chih...
#
#                                                    genre  \
# 3080   ['Action', 'Military', 'Adventure', 'Comedy', ...
# 773                               ['Thriller', 'Sci-Fi']
# 772    ['Action', 'Adventure', 'Fantasy', 'Shounen', ...
# 18278     ['Romance', 'Supernatural', 'School', 'Drama']
# 18276  ['Action', 'Drama', 'Fantasy', 'Military', 'My...
# 18067  ['Action', 'Comedy', 'Historical', 'Parody', '...
# 18066  ['Action', 'Sci-Fi', 'Comedy', 'Historical', '...
# 18065           ['Military', 'Sci-Fi', 'Space', 'Drama']
# 18064       ['Drama', 'Game', 'Seinen', 'Slice of Life']
# 18063                     ['Drama', 'School', 'Shounen']
# 3092   ['Action', 'Comedy', 'Historical', 'Parody', '...
# 14     ['Slice of Life', 'Comedy', 'Supernatural', 'D...
# 13     ['Action', 'Comedy', 'Historical', 'Parody', '...
# 12     ['Action', 'Sci-Fi', 'Comedy', 'Historical', '...
# 11     ['Action', 'Comedy', 'Historical', 'Parody', '...
# 3087   ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 3086   ['Action', 'Military', 'Sci-Fi', 'Super Power'...
# 3085    ['Mystery', 'Comedy', 'Supernatural', 'Vampire']
# 3084   ['Action', 'Demons', 'Historical', 'Shounen', ...
# 6                 ['Adventure', 'Supernatural', 'Drama']
#
#                               aired  episodes  members  popularity  ranked  \
# 3080     Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0
# 773     Apr 6, 2011 to Sep 14, 2011      24.0  1331710           7     2.0
# 772     Oct 2, 2011 to Sep 24, 2014     148.0  1052761          20     3.0
# 18278                  Aug 26, 2016       1.0  1139878          15     4.0
# 18276   Apr 29, 2019 to Jul 1, 2019      10.0   446370         175     5.0
# 18067   Apr 8, 2015 to Mar 30, 2016      51.0   281594         351     6.0
# 18066   Apr 4, 2011 to Mar 26, 2012      51.0   278110         353     7.0
# 18065   Jan 8, 1988 to Mar 17, 1997     110.0   175423         620     8.0
# 18064  Oct 14, 2017 to Mar 31, 2018      22.0   169544         657     9.0
# 18063                  Sep 17, 2016       1.0   842277          53    10.0
# 3092    Oct 4, 2012 to Mar 28, 2013      13.0   166446         667    11.0
# 14      Oct 3, 2008 to Mar 27, 2009      24.0   740101          64    12.0
# 13      Apr 4, 2006 to Mar 25, 2010     201.0   579150          97    13.0
# 12                      Jul 6, 2013       1.0   135232         833    14.0
# 11      Jan 9, 2017 to Mar 27, 2017      12.0   139309         800    15.0
# 3087    Oct 8, 2016 to Dec 10, 2016      10.0   395375         223    16.0
# 3086    Apr 6, 2008 to Sep 28, 2008      25.0   992196          27    17.0
# 3085   Aug 12, 2017 to Aug 13, 2017       7.0   189944         573    18.0
# 3084    Apr 6, 2019 to Sep 28, 2019      26.0   575037         106    19.0
# 6                      Jul 20, 2001       1.0   913212          40    20.0
#
#        score  ... Magic Ecchi  Action  Josei  Harem  Music  Yaoi  Sports  \
# 3080    9.23  ...     1     0       1      0      0      0     0       0
# 773     9.11  ...     0     0       0      0      0      0     0       0
# 772     9.11  ...     0     0       1      0      0      0     0       0
# 18278   9.09  ...     0     0       0      0      0      0     0       0
# 18276   9.07  ...     0     0       1      0      0      0     0       0
# 18067   9.05  ...     0     0       1      0      0      0     0       0
# 18066   9.04  ...     0     0       1      0      0      0     0       0
# 18065   9.03  ...     0     0       0      0      0      0     0       0
# 18064   9.02  ...     0     0       0      0      0      0     0       0
# 18063   9.01  ...     0     0       0      0      0      0     0       0
# 3092    8.98  ...     0     0       1      0      0      0     0       0
# 14      8.97  ...     0     0       0      0      0      0     0       0
# 13      8.97  ...     0     0       1      0      0      0     0       0
# 12      8.95  ...     0     0       1      0      0      0     0       0
# 11      8.94  ...     0     0       1      0      0      0     0       0
# 3087    8.94  ...     0     0       0      0      0      0     0       1
# 3086    8.93  ...     0     0       1      0      0      0     0       0
# 3085    8.93  ...     0     0       0      0      0      0     0       0
# 3084    8.92  ...     0     0       1      0      0      0     0       0
# 6       8.90  ...     0     0       0      0      0      0     0       0
#
#        Seinen  Psychological
# 3080        0              0
# 773         0              0
# 772         0              0
# 18278       0              0
# 18276       0              0
# 18067       0              0
# 18066       0              0
# 18065       0              0
# 18064       1              0
# 18063       0              0
# 3092        0              0
# 14          0              0
# 13          0              0
# 12          0              0
# 11          0              0
# 3087        0              0
# 3086        0              0
# 3085        0              0
# 3084        0              0
# 6           0              0
#
# [20 rows x 55 columns]

# %%
def get_top_rated(n, df=animes_df):
    '''
    INPUT:
    df - animes df from cells above
    n - number of recs to return
    
    OUTPUT:
    recs -  the name and img url of the all time top rated animes
    '''
    recs = []
    top_ranked = df.sort_values(by='ranked', ascending=True).drop_duplicates()
    
    for i in range(n):
        recs.append((top_ranked.iloc[i].title, top_ranked.iloc[i].img_url))
                    
    return recs

# %%
top_rated = get_top_rated(10)
print(top_rated[0])
# Out:
# [('Fullmetal Alchemist: Brotherhood', 'https://cdn.myanimelist.net/images/anime/1223/96541.jpg'), ('Steins;Gate', 'https://cdn.myanimelist.net/images/anime/5/73199.jpg'), ('Hunter x Hunter (2011)', 'https://cdn.myanimelist.net/images/anime/11/33657.jpg'), ('Kimi no Na wa.', 'https://cdn.myanimelist.net/images/anime/5/87048.jpg'), ('Shingeki no Kyojin Season 3 Part 2', 'https://cdn.myanimelist.net/images/anime/1517/100633.jpg'), ('Gintama°', 'https://cdn.myanimelist.net/images/anime/3/72078.jpg'), ("Gintama'", 'https://cdn.myanimelist.net/images/anime/4/50361.jpg'), ('Ginga Eiyuu Densetsu', 'https://cdn.myanimelist.net/images/anime/13/13225.jpg'), ('3-gatsu no Lion 2nd Season', 'https://cdn.myanimelist.net/images/anime/3/88469.jpg'), ('Koe no Katachi', 'https://cdn.myanimelist.net/images/anime/1122/96435.jpg')]

# %%
print(top_rated[5])
# Out:
# ('Gintama°', 'https://cdn.myanimelist.net/images/anime/3/72078.jpg')
